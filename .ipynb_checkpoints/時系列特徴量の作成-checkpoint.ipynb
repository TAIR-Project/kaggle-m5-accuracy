# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import psutil

# %%
cd C:/Users/minih/python_prac1/m5/git-repository/kaggle-m5-accuracy-library/library/
# Out:
# C:\Users\minih\python_prac1\m5\git-repository\kaggle-m5-accuracy-library\library

# %%
import patair

# %%
cd C:\Users\minih\python_prac1\library\m5
# Out:
# C:\Users\minih\python_prac1\library\m5

# %%
datas = pd.read_pickle('all_sales_train_validation.pickle')

# %%
datas.shape
# Out:
# (22589864, 17)

# %%
datas.head(3)
# Out:
#                                 id  item_id  dept_id  cat_id  store_id  \
# 1612   FOODS_1_001_CA_1_validation        0        0       0         0
# 32102  FOODS_1_001_CA_1_validation        0        0       0         0
# 62592  FOODS_1_001_CA_1_validation        0        0       0         0
#
#        state_id  sell_num        date  wm_yr_wk  event_name_1  event_type_1  \
# 1612          0       0.0  2014-04-26     11413            30             4
# 32102         0       0.0  2014-04-27     11413            30             4
# 62592         0       1.0  2014-04-28     11413            30             4
#
#        event_name_2  event_type_2  snap_CA  snap_TX  snap_WI  sell_price
# 1612              4             2        0        0        0    2.240234
# 32102             4             2        0        0        0    2.240234
# 62592             4             2        0        0        0    2.240234

# %%
datas['date'] = pd.to_datetime(datas['date'])

# %%
datas.dtypes
# Out:
# id                      object
# item_id                  int16
# dept_id                   int8
# cat_id                    int8
# store_id                  int8
# state_id                  int8
# d                       object
# sell_num               float64
# date            datetime64[ns]
# wm_yr_wk                 int16
# event_name_1              int8
# event_type_1              int8
# event_name_2              int8
# event_type_2              int8
# snap_CA                   int8
# snap_TX                   int8
# snap_WI                   int8
# sell_price             float16
# dtype: object

# %%
datas.shape
# Out:
# (22589864, 18)

# %%
datas.shape
# Out:
# (46027957, 17)

# %%
#maps = datas.groupby("id").groups

# %%
#list(maps.values())[0]

# %%
#base_index = datas.index

# %%
#j = 0
#for i in np.arange(30490):
 #   if j % 1000 == 0:
  #      print(j)
   # if not datas.loc[list(maps.values())[i]].isnull().sum()["sell_price"] == 0:
    #    datas.loc[list(maps.values())[i]] = datas.loc[list(maps.values())[i]].interpolate()
    #j+=1

# %%
#datas.to_pickle("all_sales_train_val_interpolate.pickle")

# %%
#datas.reset_index(inplace=True)

# %%
datas.head(3)
# Out:
#                                 id  item_id  dept_id  cat_id  store_id  \
# 1612   FOODS_1_001_CA_1_validation        0        0       0         0
# 32102  FOODS_1_001_CA_1_validation        0        0       0         0
# 62592  FOODS_1_001_CA_1_validation        0        0       0         0
#
#        state_id       d  sell_num       date  wm_yr_wk  event_name_1  \
# 1612          0  d_1184       0.0 2014-04-26     11413            30
# 32102         0  d_1185       0.0 2014-04-27     11413            30
# 62592         0  d_1186       1.0 2014-04-28     11413            30
#
#        event_type_1  event_name_2  event_type_2  snap_CA  snap_TX  snap_WI  \
# 1612              4             4             2        0        0        0
# 32102             4             4             2        0        0        0
# 62592             4             4             2        0        0        0
#
#        sell_price
# 1612     2.240234
# 32102    2.240234
# 62592    2.240234

# %%
#datas.set_index("id",inplace=True)

# %%
np.max(datas["date"])
# Out:
# Timestamp('2016-05-22 00:00:00')

# %%
#answear_val = datas[(datas["date"] >= "2016-03-28") & (datas["date"] <= "2016-04-24")]#["sell_num"]

# %%
#answear_val.shape

# %%
#answear_val.to_pickle("answear_val.pickle")

# %%
#datas.loc[((datas["date"] >= "2016-03-28")),"sell_num"] = np.NaN

# %%
#1日前の売り上げ個数を特徴に追加
#datas["prev_1"] = datas.groupby("id")["sell_num"].transform(lambda x:x.shift(1))

#2日前の売り上げ個数を特徴に追加
#datas["prev_2"] = datas.groupby("id")["sell_num"].transform(lambda x:x.shift(2))

#7日前の売り上げ個数を特徴に追加
#datas["prev_7"] = datas.groupby("id")["sell_num"].transform(lambda x:x.shift(7))


#14日前の売り上げ個数を特徴に追加
#datas["prev_14"] = datas.groupby("id")["sell_num"].transform(lambda x:x.shift(14))

#############

#28日前の売り上げ個数を特徴に追加
datas["prev_28"] = datas.groupby("id")["sell_num"].transform(lambda x:x.shift(28))

#29日前の売り上げ個数を特徴に追加
#datas["prev_29"] = datas.groupby("id")["sell_num"].transform(lambda x:x.shift(29))

#30日前の売り上げ個数を特徴に追加
#datas["prev_30"] = datas.groupby("id")["sell_num"].transform(lambda x:x.shift(30))

#35日前の売り上げ個数を特徴に追加
#datas["prev_35"] = datas.groupby("id")["sell_num"].transform(lambda x:x.shift(35))

#半年前(182日前)の売り上げ個数を特徴に追加
#datas["prev_182"] = datas.groupby("id")["sell_num"].transform(lambda x:x.shift(182))

#1年前(365日前)の売り上げ個数を特徴に追加
#datas["prev_365"] = datas.groupby("id")["sell_num"].transform(lambda x:x.shift(365))

# %%
datas = patair.reduce_mem_usage(datas,True)
# Out:
# Mem. usage decreased to 969.45 Mb (0.0% reduction)

# %%
#1日前の価格を特徴に追加
datas["p_prev_1"] = datas.groupby("id")["sell_price"].transform(lambda x:x.shift(1))

#2日前の価格を特徴に追加
#datas["p_prev_2"] = datas.groupby("id")["sell_price"].transform(lambda x:x.shift(2))

#3日前の価格を特徴に追加
#datas["p_prev_3"] = datas.groupby("id")["sell_price"].transform(lambda x:x.shift(3))

#7日前の価格を特徴に追加
#datas["p_prev_7"] = datas.groupby("id")["sell_price"].transform(lambda x:x.shift(7))

#14日前の価格を特徴に追加
#datas["p_prev_14"] = datas.groupby("id")["sell_price"].transform(lambda x:x.shift(14))

#28日前の価格を特徴に追加
#datas["p_prev_28"] = datas.groupby("id")["sell_price"].transform(lambda x:x.shift(28))
#あまりラグを大きくしすぎるとアイテムによってはデータが全然ない状況に...

# %%
#for size in [7, 30]:
#        datas[f"rolling_mean_t{size}"] = datas.groupby(["id"])["sell_num"].transform(
#            lambda x: x.shift(7).rolling(size).mean()
#        )
for size in [7, 14]:
        datas[f"rolling_mean_t{size}"] = datas.groupby(["id"])["sell_num"].transform(
            lambda x: x.shift(28).rolling(size).mean()
        )
#for size in [7, 30, 60, 90, 180]:
#        datas[f"rolling_mean_t{size}"] = datas.groupby(["id"])["sell_num"].transform(
#            lambda x: x.shift(28).rolling(size).mean()
#        )

# %%
#for size in [7, 30]:
#        datas[f"rolling_std_t{size}"] = datas.groupby(["id"])["sell_num"].transform(
#            lambda x: x.shift(7).rolling(size).std()
#        )
for size in [7, 14]:
        datas[f"rolling_std_t{size}"] = datas.groupby(["id"])["sell_num"].transform(
            lambda x: x.shift(28).rolling(size).std()
        )

# %%
datas["price_change_t1"] = (datas["p_prev_1"] - datas["sell_price"]) / (
        datas["p_prev_1"]
    )

# %%
#datas["rolling_price_max_t365"] = datas.groupby(["id"])["sell_price"].transform(
#        lambda x: x.shift(1).rolling(365).max()
#)

# %%
#datas["price_change_t365"] = (datas["rolling_price_max_t365"] - datas["sell_price"]) / (
#        datas["rolling_price_max_t365"]
#)

# %%
datas["rolling_price_std_t7"] = datas.groupby(["id"])["sell_price"].transform(
        lambda x: x.rolling(7).std()
    )
datas["rolling_price_std_t30"] = datas.groupby(["id"])["sell_price"].transform(
        lambda x: x.rolling(30).std()
    )

# %%
datas.columns
# Out:
# Index(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'd',
#        'sell_num', 'date', 'wm_yr_wk', 'event_name_1', 'event_type_1',
#        'event_name_2', 'event_type_2', 'snap_CA', 'snap_TX', 'snap_WI',
#        'sell_price', 'prev_28', 'prev_29', 'prev_35', 'prev_182', 'prev_365',
#        'p_prev_1', 'rolling_mean_t7', 'rolling_mean_t30', 'rolling_mean_t60',
#        'rolling_mean_t90', 'rolling_mean_t180', 'price_change_t1',
#        'rolling_price_max_t365', 'price_change_t365', 'rolling_price_std_t7',
#        'rolling_price_std_t30'],
#       dtype='object')

# %%
datas
# Out:
#                                        id  item_id  dept_id  cat_id  store_id  \
# 1612          FOODS_1_001_CA_1_validation        0        0       0         0
# 32102         FOODS_1_001_CA_1_validation        0        0       0         0
# 62592         FOODS_1_001_CA_1_validation        0        0       0         0
# 93082         FOODS_1_001_CA_1_validation        0        0       0         0
# 123572        FOODS_1_001_CA_1_validation        0        0       0         0
# ...                                   ...      ...      ...     ...       ...
# 22988022  HOUSEHOLD_2_516_WI_3_validation     3048        6       2         9
# 23018512  HOUSEHOLD_2_516_WI_3_validation     3048        6       2         9
# 23049002  HOUSEHOLD_2_516_WI_3_validation     3048        6       2         9
# 23079492  HOUSEHOLD_2_516_WI_3_validation     3048        6       2         9
# 23109982  HOUSEHOLD_2_516_WI_3_validation     3048        6       2         9
#
#           state_id       d  sell_num        date  wm_yr_wk  ...  prev_14  \
# 1612             0  d_1184       0.0  2014-04-26     11413  ...      NaN
# 32102            0  d_1185       0.0  2014-04-27     11413  ...      NaN
# 62592            0  d_1186       1.0  2014-04-28     11413  ...      NaN
# 93082            0  d_1187       1.0  2014-04-29     11413  ...      NaN
# 123572           0  d_1188       1.0  2014-04-30     11413  ...      NaN
# ...            ...     ...       ...         ...       ...  ...      ...
# 22988022         2  d_1937       NaN  2016-05-18     11616  ...      NaN
# 23018512         2  d_1938       NaN  2016-05-19     11616  ...      NaN
# 23049002         2  d_1939       NaN  2016-05-20     11616  ...      NaN
# 23079492         2  d_1940       NaN  2016-05-21     11617  ...      NaN
# 23109982         2  d_1941       NaN  2016-05-22     11617  ...      NaN
#
#           prev_28  p_prev_1  rolling_mean_t7  rolling_mean_t30  \
# 1612          NaN       NaN              NaN               NaN
# 32102         NaN  2.240234              NaN               NaN
# 62592         NaN  2.240234              NaN               NaN
# 93082         NaN  2.240234              NaN               NaN
# 123572        NaN  2.240234              NaN               NaN
# ...           ...       ...              ...               ...
# 22988022      0.0  5.941406              NaN               NaN
# 23018512      0.0  5.941406              NaN               NaN
# 23049002      0.0  5.941406              NaN               NaN
# 23079492      0.0  5.941406              NaN               NaN
# 23109982      0.0  5.941406              NaN               NaN
#
#           rolling_std_t7  rolling_std_t30  price_change_t1  \
# 1612                 NaN              NaN              NaN
# 32102                NaN              NaN              0.0
# 62592                NaN              NaN              0.0
# 93082                NaN              NaN              0.0
# 123572               NaN              NaN              0.0
# ...                  ...              ...              ...
# 22988022             NaN              NaN              0.0
# 23018512             NaN              NaN              0.0
# 23049002             NaN              NaN              0.0
# 23079492             NaN              NaN              0.0
# 23109982             NaN              NaN              0.0
#
#           rolling_price_std_t7  rolling_price_std_t30
# 1612                       NaN                    NaN
# 32102                      NaN                    NaN
# 62592                      NaN                    NaN
# 93082                      NaN                    NaN
# 123572                     NaN                    NaN
# ...                        ...                    ...
# 22988022                   0.0                    0.0
# 23018512                   0.0                    0.0
# 23049002                   0.0                    0.0
# 23079492                   0.0                    0.0
# 23109982                   0.0                    0.0
#
# [22589864 rows x 31 columns]

# %%
 attrs = [
        "year",
        "quarter",
        "month",
        "week",
        "day",
        "dayofweek",
        #"is_year_end",
        #"is_year_start",
        #"is_quarter_end",
        #"is_quarter_start",
        #"is_month_end",
        #"is_month_start",
    ]

for attr in attrs:
    dtype = np.int16 if attr == "year" else np.int8
    datas[attr] = getattr(datas["date"].dt, attr).astype(dtype)

datas["is_weekend"] = datas["dayofweek"].isin([5, 6]).astype(np.int8)

# %%
datas = patair.reduce_mem_usage(datas,True)
# Out:
# Mem. usage decreased to 1486.49 Mb (0.0% reduction)

# %%
datas.columns
# Out:
# Index(['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'd',
#        'sell_num', 'date', 'wm_yr_wk', 'event_name_1', 'event_type_1',
#        'event_name_2', 'event_type_2', 'snap_CA', 'snap_TX', 'snap_WI',
#        'sell_price', 'prev_7', 'prev_14', 'prev_28', 'p_prev_1',
#        'rolling_mean_t7', 'rolling_mean_t30', 'price_change_t1',
#        'rolling_std_t7', 'rolling_std_t30', 'rolling_price_std_t7',
#        'rolling_price_std_t30', 'year', 'quarter', 'month', 'week', 'day',
#        'dayofweek', 'is_year_end', 'is_year_start', 'is_quarter_end',
#        'is_quarter_start', 'is_month_end', 'is_month_start', 'is_weekend'],
#       dtype='object')

# %%
#nanのデータをdrop
#datas.dropna(subset=[ 'sell_price', 'prev_28', 'prev_29', 'prev_35',
 #      'prev_182', 'prev_365', 'p_prev_1', 'rolling_mean_t7',
  #     'rolling_mean_t30', 'rolling_mean_t60', 'rolling_mean_t90',
   #    'rolling_mean_t180', 'price_change_t1',
    #   'rolling_price_std_t7', 'rolling_price_std_t30'],inplace=True)

# %%
#datas.drop(['rolling_price_max_t365','price_change_t365'],axis=1,inplace=True)

# %%
datas.shape

# %%
datas.drop("wm_yr_wk",axis=1,inplace=True)

# %%
datas.to_pickle('all_sales_train_validation_translated_contain_null.pickle')

# %%
buff = datas[datas["id"] == "FOODS_1_001_CA_1_validation"][['date','sell_num', 'sell_price','prev_28', 'p_prev_1','rolling_mean_t7', 
               'rolling_mean_t30', 'price_change_t1','rolling_std_t7', 'rolling_std_t30',
               'rolling_price_std_t7', 'rolling_price_std_t30', 'price_change_t1', 'rolling_price_std_t7']]

# %%
#最大ラグを早めに出しておこう！！
buff.head(37)
# Out:
#               date  sell_num  sell_price  prev_28  p_prev_1  rolling_mean_t7  \
# 1612    2014-04-26       0.0    2.240234      NaN       NaN              NaN
# 32102   2014-04-27       0.0    2.240234      NaN  2.240234              NaN
# 62592   2014-04-28       1.0    2.240234      NaN  2.240234              NaN
# 93082   2014-04-29       1.0    2.240234      NaN  2.240234              NaN
# 123572  2014-04-30       1.0    2.240234      NaN  2.240234              NaN
# 154062  2014-05-01       1.0    2.240234      NaN  2.240234              NaN
# 184552  2014-05-02       3.0    2.240234      NaN  2.240234              NaN
# 215042  2014-05-03       1.0    2.240234      NaN  2.240234              NaN
# 245532  2014-05-04       1.0    2.240234      NaN  2.240234              NaN
# 276022  2014-05-05       0.0    2.240234      NaN  2.240234              NaN
# 306512  2014-05-06       0.0    2.240234      NaN  2.240234              NaN
# 337002  2014-05-07       2.0    2.240234      NaN  2.240234              NaN
# 367492  2014-05-08       0.0    2.240234      NaN  2.240234              NaN
# 397982  2014-05-09       1.0    2.240234      NaN  2.240234              NaN
# 428472  2014-05-10       2.0    2.240234      NaN  2.240234              NaN
# 458962  2014-05-11       0.0    2.240234      NaN  2.240234              NaN
# 489452  2014-05-12       1.0    2.240234      NaN  2.240234              NaN
# 519942  2014-05-13       2.0    2.240234      NaN  2.240234              NaN
# 550432  2014-05-14       0.0    2.240234      NaN  2.240234              NaN
# 580922  2014-05-15       0.0    2.240234      NaN  2.240234              NaN
# 611412  2014-05-16       0.0    2.240234      NaN  2.240234              NaN
# 641902  2014-05-17       2.0    2.240234      NaN  2.240234              NaN
# 672392  2014-05-18       2.0    2.240234      NaN  2.240234              NaN
# 702882  2014-05-19       3.0    2.240234      NaN  2.240234              NaN
# 733372  2014-05-20       1.0    2.240234      NaN  2.240234              NaN
# 763862  2014-05-21       0.0    2.240234      NaN  2.240234              NaN
# 794352  2014-05-22       1.0    2.240234      NaN  2.240234              NaN
# 824842  2014-05-23       0.0    2.240234      NaN  2.240234              NaN
# 855332  2014-05-24       0.0    2.240234      0.0  2.240234              NaN
# 885822  2014-05-25       0.0    2.240234      0.0  2.240234              NaN
# 916312  2014-05-26       0.0    2.240234      1.0  2.240234              NaN
# 946802  2014-05-27       0.0    2.240234      1.0  2.240234              NaN
# 977292  2014-05-28       0.0    2.240234      1.0  2.240234              NaN
# 1007782 2014-05-29       5.0    2.240234      1.0  2.240234              NaN
# 1038272 2014-05-30       1.0    2.240234      3.0  2.240234         1.000000
# 1068762 2014-05-31       0.0    2.240234      1.0  2.240234         1.142578
# 1099252 2014-06-01       1.0    2.240234      1.0  2.240234         1.286133
# 1129742 2014-06-02       1.0    2.240234      0.0  2.240234         1.142578
# 1160232 2014-06-03       0.0    2.240234      0.0  2.240234         1.000000
# 1190722 2014-06-04       0.0    2.240234      2.0  2.240234         1.142578
# 1221212 2014-06-05       0.0    2.240234      0.0  2.240234         1.000000
# 1251702 2014-06-06       2.0    2.240234      1.0  2.240234         0.714355
# 1282192 2014-06-07       2.0    2.240234      2.0  2.240234         0.856934
# 1312682 2014-06-08       1.0    2.240234      0.0  2.240234         0.714355
# 1343172 2014-06-09       0.0    2.240234      1.0  2.240234         0.856934
# 1373662 2014-06-10       0.0    2.240234      2.0  2.240234         1.142578
# 1404152 2014-06-11       0.0    2.240234      0.0  2.240234         0.856934
# 1434642 2014-06-12       0.0    2.240234      0.0  2.240234         0.856934
# 1465132 2014-06-13       1.0    2.240234      0.0  2.240234         0.714355
# 1495622 2014-06-14       2.0    2.240234      2.0  2.240234         0.714355
# 1526112 2014-06-15       4.0    2.240234      2.0  2.240234         1.000000
# 1556602 2014-06-16       1.0    2.240234      3.0  2.240234         1.286133
# 1587092 2014-06-17       1.0    2.240234      1.0  2.240234         1.142578
# 1617582 2014-06-18       1.0    2.240234      0.0  2.240234         1.142578
# 1648072 2014-06-19       0.0    2.240234      1.0  2.240234         1.286133
# 1678562 2014-06-20       1.0    2.240234      0.0  2.240234         1.286133
# 1709052 2014-06-21       0.0    2.240234      0.0  2.240234         1.000000
# 1739542 2014-06-22       1.0    2.240234      0.0  2.240234         0.714355
#
#          rolling_mean_t30  price_change_t1  rolling_std_t7  rolling_std_t30  \
# 1612                  NaN              NaN             NaN              NaN
# 32102                 NaN              0.0             NaN              NaN
# 62592                 NaN              0.0             NaN              NaN
# 93082                 NaN              0.0             NaN              NaN
# 123572                NaN              0.0             NaN              NaN
# 154062                NaN              0.0             NaN              NaN
# 184552                NaN              0.0             NaN              NaN
# 215042                NaN              0.0             NaN              NaN
# 245532                NaN              0.0             NaN              NaN
# 276022                NaN              0.0             NaN              NaN
# 306512                NaN              0.0             NaN              NaN
# 337002                NaN              0.0             NaN              NaN
# 367492                NaN              0.0             NaN              NaN
# 397982                NaN              0.0             NaN              NaN
# 428472                NaN              0.0             NaN              NaN
# 458962                NaN              0.0             NaN              NaN
# 489452                NaN              0.0             NaN              NaN
# 519942                NaN              0.0             NaN              NaN
# 550432                NaN              0.0             NaN              NaN
# 580922                NaN              0.0             NaN              NaN
# 611412                NaN              0.0             NaN              NaN
# 641902                NaN              0.0             NaN              NaN
# 672392                NaN              0.0             NaN              NaN
# 702882                NaN              0.0             NaN              NaN
# 733372                NaN              0.0             NaN              NaN
# 763862                NaN              0.0             NaN              NaN
# 794352                NaN              0.0             NaN              NaN
# 824842                NaN              0.0             NaN              NaN
# 855332                NaN              0.0             NaN              NaN
# 885822                NaN              0.0             NaN              NaN
# 916312                NaN              0.0             NaN              NaN
# 946802                NaN              0.0             NaN              NaN
# 977292                NaN              0.0             NaN              NaN
# 1007782               NaN              0.0             NaN              NaN
# 1038272               NaN              0.0        1.000000              NaN
# 1068762               NaN              0.0        0.899902              NaN
# 1099252               NaN              0.0        0.755859              NaN
# 1129742               NaN              0.0        0.899902              NaN
# 1160232               NaN              0.0        1.000000              NaN
# 1190722               NaN              0.0        1.069336              NaN
# 1221212               NaN              0.0        1.154297              NaN
# 1251702               NaN              0.0        0.755859              NaN
# 1282192               NaN              0.0        0.899902              NaN
# 1312682               NaN              0.0        0.951172              NaN
# 1343172               NaN              0.0        0.899902              NaN
# 1373662               NaN              0.0        0.899902              NaN
# 1404152               NaN              0.0        0.899902              NaN
# 1434642               NaN              0.0        0.899902              NaN
# 1465132               NaN              0.0        0.951172              NaN
# 1495622               NaN              0.0        0.951172              NaN
# 1526112               NaN              0.0        1.000000              NaN
# 1556602               NaN              0.0        1.253906              NaN
# 1587092               NaN              0.0        1.214844              NaN
# 1617582               NaN              0.0        1.214844              NaN
# 1648072               NaN              0.0        1.112305              NaN
# 1678562               NaN              0.0        1.112305              NaN
# 1709052               NaN              0.0        1.154297              NaN
# 1739542          0.866699              0.0        1.112305         0.937012
#
#          rolling_price_std_t7  rolling_price_std_t30  price_change_t1  \
# 1612                      NaN                    NaN              NaN
# 32102                     NaN                    NaN              0.0
# 62592                     NaN                    NaN              0.0
# 93082                     NaN                    NaN              0.0
# 123572                    NaN                    NaN              0.0
# 154062                    NaN                    NaN              0.0
# 184552                    0.0                    NaN              0.0
# 215042                    0.0                    NaN              0.0
# 245532                    0.0                    NaN              0.0
# 276022                    0.0                    NaN              0.0
# 306512                    0.0                    NaN              0.0
# 337002                    0.0                    NaN              0.0
# 367492                    0.0                    NaN              0.0
# 397982                    0.0                    NaN              0.0
# 428472                    0.0                    NaN              0.0
# 458962                    0.0                    NaN              0.0
# 489452                    0.0                    NaN              0.0
# 519942                    0.0                    NaN              0.0
# 550432                    0.0                    NaN              0.0
# 580922                    0.0                    NaN              0.0
# 611412                    0.0                    NaN              0.0
# 641902                    0.0                    NaN              0.0
# 672392                    0.0                    NaN              0.0
# 702882                    0.0                    NaN              0.0
# 733372                    0.0                    NaN              0.0
# 763862                    0.0                    NaN              0.0
# 794352                    0.0                    NaN              0.0
# 824842                    0.0                    NaN              0.0
# 855332                    0.0                    NaN              0.0
# 885822                    0.0                    0.0              0.0
# 916312                    0.0                    0.0              0.0
# 946802                    0.0                    0.0              0.0
# 977292                    0.0                    0.0              0.0
# 1007782                   0.0                    0.0              0.0
# 1038272                   0.0                    0.0              0.0
# 1068762                   0.0                    0.0              0.0
# 1099252                   0.0                    0.0              0.0
# 1129742                   0.0                    0.0              0.0
# 1160232                   0.0                    0.0              0.0
# 1190722                   0.0                    0.0              0.0
# 1221212                   0.0                    0.0              0.0
# 1251702                   0.0                    0.0              0.0
# 1282192                   0.0                    0.0              0.0
# 1312682                   0.0                    0.0              0.0
# 1343172                   0.0                    0.0              0.0
# 1373662                   0.0                    0.0              0.0
# 1404152                   0.0                    0.0              0.0
# 1434642                   0.0                    0.0              0.0
# 1465132                   0.0                    0.0              0.0
# 1495622                   0.0                    0.0              0.0
# 1526112                   0.0                    0.0              0.0
# 1556602                   0.0                    0.0              0.0
# 1587092                   0.0                    0.0              0.0
# 1617582                   0.0                    0.0              0.0
# 1648072                   0.0                    0.0              0.0
# 1678562                   0.0                    0.0              0.0
# 1709052                   0.0                    0.0              0.0
# 1739542                   0.0                    0.0              0.0
#
#          rolling_price_std_t7
# 1612                      NaN
# 32102                     NaN
# 62592                     NaN
# 93082                     NaN
# 123572                    NaN
# 154062                    NaN
# 184552                    0.0
# 215042                    0.0
# 245532                    0.0
# 276022                    0.0
# 306512                    0.0
# 337002                    0.0
# 367492                    0.0
# 397982                    0.0
# 428472                    0.0
# 458962                    0.0
# 489452                    0.0
# 519942                    0.0
# 550432                    0.0
# 580922                    0.0
# 611412                    0.0
# 641902                    0.0
# 672392                    0.0
# 702882                    0.0
# 733372                    0.0
# 763862                    0.0
# 794352                    0.0
# 824842                    0.0
# 855332                    0.0
# 885822                    0.0
# 916312                    0.0
# 946802                    0.0
# 977292                    0.0
# 1007782                   0.0
# 1038272                   0.0
# 1068762                   0.0
# 1099252                   0.0
# 1129742                   0.0
# 1160232                   0.0
# 1190722                   0.0
# 1221212                   0.0
# 1251702                   0.0
# 1282192                   0.0
# 1312682                   0.0
# 1343172                   0.0
# 1373662                   0.0
# 1404152                   0.0
# 1434642                   0.0
# 1465132                   0.0
# 1495622                   0.0
# 1526112                   0.0
# 1556602                   0.0
# 1587092                   0.0
# 1617582                   0.0
# 1648072                   0.0
# 1678562                   0.0
# 1709052                   0.0
# 1739542                   0.0

# %%
buff.to_csv("try.csv")

# %%
#datas.to_pickle('all_sales_train_validation_translated.pickle')
