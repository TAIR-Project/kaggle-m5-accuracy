# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import lightgbm as lgb
from sklearn import preprocessing, metrics
from sklearn.metrics import r2_score
from sklearn.preprocessing import LabelEncoder
import gc
from tqdm import tqdm
from scipy.sparse import csr_matrix
from  datetime import datetime, timedelta

# %%
cd C:/Users/minih/python_prac1/m5/git-repository/kaggle-m5-accuracy-library/library/
# Out:
# C:\Users\minih\python_prac1\m5\git-repository\kaggle-m5-accuracy-library\library

# %%
from patair import reduce_mem_usage

# %%
cd C:\Users\minih\python_prac1\library\m5
# Out:
# C:\Users\minih\python_prac1\library\m5

# %%
datas = pd.read_pickle("all_sales_train_validation_translated_contain_null.pickle")

# %%
datas.head(10)
# Out:
#                                  id  item_id  dept_id  cat_id  store_id  \
# 1612    FOODS_1_001_CA_1_validation        0        0       0         0
# 32102   FOODS_1_001_CA_1_validation        0        0       0         0
# 62592   FOODS_1_001_CA_1_validation        0        0       0         0
# 93082   FOODS_1_001_CA_1_validation        0        0       0         0
# 123572  FOODS_1_001_CA_1_validation        0        0       0         0
# 154062  FOODS_1_001_CA_1_validation        0        0       0         0
# 184552  FOODS_1_001_CA_1_validation        0        0       0         0
# 215042  FOODS_1_001_CA_1_validation        0        0       0         0
# 245532  FOODS_1_001_CA_1_validation        0        0       0         0
# 276022  FOODS_1_001_CA_1_validation        0        0       0         0
#
#         state_id  sell_num       date  event_name_1  event_type_1  ...  \
# 1612           0         3 2011-01-29            30             4  ...
# 32102          0         0 2011-01-30            30             4  ...
# 62592          0         0 2011-01-31            30             4  ...
# 93082          0         1 2011-02-01            30             4  ...
# 123572         0         4 2011-02-02            30             4  ...
# 154062         0         2 2011-02-03            30             4  ...
# 184552         0         0 2011-02-04            30             4  ...
# 215042         0         2 2011-02-05            30             4  ...
# 245532         0         0 2011-02-06            26             3  ...
# 276022         0         0 2011-02-07            30             4  ...
#
#         price_change_t1  rolling_price_std_t7  rolling_price_std_t30  year  \
# 1612                NaN                   NaN                    NaN  2011
# 32102               0.0                   NaN                    NaN  2011
# 62592               0.0                   NaN                    NaN  2011
# 93082               0.0                   NaN                    NaN  2011
# 123572              0.0                   NaN                    NaN  2011
# 154062              0.0                   NaN                    NaN  2011
# 184552              0.0                   0.0                    NaN  2011
# 215042              0.0                   0.0                    NaN  2011
# 245532              0.0                   0.0                    NaN  2011
# 276022              0.0                   0.0                    NaN  2011
#
#         quarter  month  week  day  dayofweek  is_weekend
# 1612          1      1     4   29          5           1
# 32102         1      1     4   30          6           1
# 62592         1      1     5   31          0           0
# 93082         1      2     5    1          1           0
# 123572        1      2     5    2          2           0
# 154062        1      2     5    3          3           0
# 184552        1      2     5    4          4           0
# 215042        1      2     5    5          5           1
# 245532        1      2     5    6          6           1
# 276022        1      2     6    7          0           0
#
# [10 rows x 36 columns]

# %%
datas.tail(3)
# Out:
#                                        id  item_id  dept_id  cat_id  store_id  \
# 58264952  HOUSEHOLD_2_516_WI_3_validation     3048        6       2         9
# 58295442  HOUSEHOLD_2_516_WI_3_validation     3048        6       2         9
# 58325932  HOUSEHOLD_2_516_WI_3_validation     3048        6       2         9
#
#           state_id  sell_num       date  event_name_1  event_type_1  ...  \
# 58264952         2         0 2016-04-22            30             4  ...
# 58295442         2         0 2016-04-23            30             4  ...
# 58325932         2         0 2016-04-24            30             4  ...
#
#           price_change_t1  rolling_price_std_t7  rolling_price_std_t30  year  \
# 58264952              0.0                   0.0                    0.0  2016
# 58295442              0.0                   0.0                    0.0  2016
# 58325932              0.0                   0.0                    0.0  2016
#
#           quarter  month  week  day  dayofweek  is_weekend
# 58264952        2      4    16   22          4           0
# 58295442        2      4    16   23          5           1
# 58325932        2      4    16   24          6           1
#
# [3 rows x 36 columns]

# %%
for i, state in enumerate(["CA", "TX", "WI"]):
    datas[datas["state_id"]==i].to_pickle(f"dataset_{state}_contain_null.pickle")
