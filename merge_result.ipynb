# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from  datetime import datetime, timedelta
from sklearn.metrics import r2_score
from sklearn.preprocessing import LabelEncoder
# Out:
# C:\Users\minih\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\minih\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
cd C:/Users/minih/python_prac1/library/m5/
# Out:
# C:\Users\minih\python_prac1\library\m5

# %%
CA_data = pd.read_pickle("result_f_CA.pickle")
TX_data = pd.read_pickle("result_f_TX.pickle")
WI_data = pd.read_pickle("result_f_WI.pickle")

# %%
CA_data
# Out:
#                                     id        F1        F2        F3  \
# 1451324  HOBBIES_1_001_CA_1_validation  0.885436  0.800952  0.809509
# 1451325  HOBBIES_1_002_CA_1_validation  0.138977  0.132028  0.166936
# 1451326  HOBBIES_1_003_CA_1_validation  0.458050  0.508421  0.515245
# 1451327  HOBBIES_1_004_CA_1_validation  1.877550  1.716038  1.631901
# 1451328  HOBBIES_1_005_CA_1_validation  1.041530  0.948577  0.935452
# ...                                ...       ...       ...       ...
# 1463515    FOODS_3_823_CA_4_validation  1.273039  1.133252  1.092964
# 1463516    FOODS_3_824_CA_4_validation  0.561120  0.528039  0.560093
# 1463517    FOODS_3_825_CA_4_validation  0.554012  0.542259  0.556519
# 1463518    FOODS_3_826_CA_4_validation  1.945723  1.767259  1.907998
# 1463519    FOODS_3_827_CA_4_validation  1.224696  1.042755  1.053176
#
#                F4        F5        F6        F7        F8        F9  ...  \
# ...

# %%
after = pd.read_csv("sample_submission.csv")

# %%
after = after.loc[30490:]

# %%
after
# Out:
#                                   id  F1  F2  F3  F4  F5  F6  F7  F8  F9  ...  \
# 30490  HOBBIES_1_001_CA_1_evaluation   0   0   0   0   0   0   0   0   0  ...
# 30491  HOBBIES_1_002_CA_1_evaluation   0   0   0   0   0   0   0   0   0  ...
# 30492  HOBBIES_1_003_CA_1_evaluation   0   0   0   0   0   0   0   0   0  ...
# 30493  HOBBIES_1_004_CA_1_evaluation   0   0   0   0   0   0   0   0   0  ...
# 30494  HOBBIES_1_005_CA_1_evaluation   0   0   0   0   0   0   0   0   0  ...
# ...                              ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...
# 60975    FOODS_3_823_WI_3_evaluation   0   0   0   0   0   0   0   0   0  ...
# 60976    FOODS_3_824_WI_3_evaluation   0   0   0   0   0   0   0   0   0  ...
# 60977    FOODS_3_825_WI_3_evaluation   0   0   0   0   0   0   0   0   0  ...
# 60978    FOODS_3_826_WI_3_evaluation   0   0   0   0   0   0   0   0   0  ...
# 60979    FOODS_3_827_WI_3_evaluation   0   0   0   0   0   0   0   0   0  ...
#
# ...

# %%
result = pd.concat([CA_data,TX_data,WI_data,after])

# %%
result
# Out:
#                                     id        F1        F2        F3  \
# 1451324  HOBBIES_1_001_CA_1_validation  0.885436  0.800952  0.809509
# 1451325  HOBBIES_1_002_CA_1_validation  0.138977  0.132028  0.166936
# 1451326  HOBBIES_1_003_CA_1_validation  0.458050  0.508421  0.515245
# 1451327  HOBBIES_1_004_CA_1_validation  1.877550  1.716038  1.631901
# 1451328  HOBBIES_1_005_CA_1_validation  1.041530  0.948577  0.935452
# ...                                ...       ...       ...       ...
# 60975      FOODS_3_823_WI_3_evaluation  0.000000  0.000000  0.000000
# 60976      FOODS_3_824_WI_3_evaluation  0.000000  0.000000  0.000000
# 60977      FOODS_3_825_WI_3_evaluation  0.000000  0.000000  0.000000
# 60978      FOODS_3_826_WI_3_evaluation  0.000000  0.000000  0.000000
# 60979      FOODS_3_827_WI_3_evaluation  0.000000  0.000000  0.000000
#
#                F4        F5        F6        F7        F8        F9  ...  \
# ...

# %%
product = pd.read_pickle("product.pickle")

# %%
result.to_csv("submission12.csv", index=False)

# %%
other = pd.read_csv("submission_v1.csv")

# %%
result = result.head(30490)

# %%
other = other.head(30490)

# %%
len(CA_data)
# Out:
# 12196

# %%
len(TX_data)
# Out:
# 9147

# %%
result.reset_index(inplace=True)

# %%
result.drop("index",axis=1,inplace=True)
# Out:
# C:\Users\minih\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
result_CA = result.loc[0:12195,:]
other_CA = other.loc[0:12195,:]

# %%
result_TX = result.loc[12196:21342,:]
other_TX = other.loc[12196:21342,:]

# %%
result_WI = result.loc[21343:,:]
other_WI = other.loc[21343:,:]

# %%
#R値グラフの表示
max_val = np.max(result_WI["F2"])
if max_val < np.max(other_WI["F2"]):
    max_val = np.max(other_WI["F2"])

plt.scatter(result_WI["F2"],other_WI["F2"])
plt.plot(np.arange(0,max_val),np.arange(0,max_val),color='red')
plt.xlabel("predict")
plt.ylabel("real")
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
res

# %%
mean_CA = []
for i in np.arange(28):
    mean_CA.append(r2_score(result_CA[f"F{i+1}"]*1.02, other_CA[f"F{i+1}"]))
np.mean(mean_CA)
# Out:
# 0.9479319663151894

# %%
mean_TX = []
for i in np.arange(28):
    mean_TX.append(r2_score(result_TX[f"F{i+1}"]*1.02, other_TX[f"F{i+1}"]))
np.mean(mean_TX)
# Out:
# 0.9441959806645152

# %%
mean_WI = []
for i in np.arange(28):
    mean_WI.append(r2_score(result_WI[f"F{i+1}"]*1.02, other_WI[f"F{i+1}"]))
np.mean(mean_WI)
# Out:
# 0.9232961769199219

# %%
r2_score(pd.concat([result_CA,result_TX,other_WI,after])["F1"].head(30490), other["F1"])
# Out:
# 0.9557459330545679

# %%
for column in result_magic.columns[1:]:
    result_magic[column] = result_magic[column].apply(lambda x:x*1.02)

# %%
result_magic.to_csv("submission13.csv", index=False)

# %%
my_best = pd.read_csv("new_submittion4.csv")

# %%
my_best = my_best.head(30490)

# %%
r2_score(other["F1"],my_best["F1"])
# Out:
# 0.9225112789834382

# %%
mean = []
for i in np.arange(28):
    mean.append(r2_score(other[f"F{i+1}"], my_best[f"F{i+1}"]))
np.mean(mean)
# Out:
# 0.9293072184431972

# %%
mean
# Out:
# [0.9225112789834382,
#  0.9196488484390271,
#  0.9407394740324048,
#  0.940357775464644,
#  0.9362467624197239,
#  0.9411531758199067,
#  0.9052102390687748,
#  0.9288538908497189,
#  0.9255488409111803,
#  0.9191307682784154,
#  0.9344685885657077,
#  0.939733056005188,
#  0.9263628181312278,
#  0.9186296270187001,
#  0.9365522926820551,
#  0.8641950355782868,
#  0.9278459784358042,
#  0.9347455073303247,
#  0.9325118888660398,
#  0.9360900720811139,
#  0.9335893335576204,
#  0.9365571984143763,
#  0.9246764237343797,
#  0.9436613691574018,
#  0.936965301503472,
#  0.9375430227566319,
#  0.9446119192713247,
#  0.9324616290526286]
